# %% [markdown]
# ![enunciado1.11.png](data:image/png;base64,...)

# %% [markdown]
# a. $S$ no puede producir una hipotesis que pueda garantizar que se desempeñe una mejor que una alateoria en algún punto fuera de $D$, exiteste un caso donde no se cumple, debemos considerar un $f$ que tiene $25+1$, pero el valor da -1, el algoritmo $S$ asignará la hipotesis más justa como $h_1$, pero es la hipotesis incorrecta fuera de $D$, en su contraparte el algoritmo $C$, tiene una probabilidad del $0.5$, por lo que acertara la mitad de veces. Por lo que el algoritmo aleatorio tendrá mejor desempeño que el inteligente.

# %% [markdown]
# b. Sí es posible que la hipotesis que produce $C$ resulte ser mejor que la hipotesis que produce $S$, en este caso donde $y_n = +1$, por lo que en el caso de que el algoritmo $S$ escoja la hipotesis $h_1$, por lo que en el algoritmo $C$ será correcta en $D$, y el algoritmo $S$ se equivocará dentro de este dominio.

# %% [markdown]
# c. Con una distribución de probabilidad de $p = 0.9$, en donde todos los ejemplos de $D$ tienen una clasificación $y += 1$, entonces sabemos que el algoritmo $S$ escogera la hipotesis $h_1$, por lo que $C$ escogerá $h_2$. Con $p = 0.9$ el algoritmo $S$ acertará con la probabilidad de 0.9, mientras que el $C$, con la $h_2$, solo lo hará un 0.1, así que $P[ [P[S]=P[h_1] ] > [P[C] = P[h_2]]] = 1$, entonces el algoritmo $S$ siempre generará una mejor hipotesis que el $C$.

# %% [markdown]
# d. Para que $C$ produzca una mejor hipotesis que $S$, la probanilida $p$ debe ser menor que $0.5$, generando $P[P[S] < P[C]] = 1$.
